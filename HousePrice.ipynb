# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use(‘ggplot')
# Out:
#   File "/var/folders/n7/l50pjwrd7z55vf740b4n06y00000gn/T/ipykernel_20594/182107532.py", line 1
#     plt.style.use(‘ggplot')
#                   ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
plt.style.use(‘ggplot')
# Out:
#   File "/var/folders/n7/l50pjwrd7z55vf740b4n06y00000gn/T/ipykernel_20594/182107532.py", line 1
#     plt.style.use(‘ggplot')
#                   ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
import matplotlib.pyplot as plt
plt.style.use(‘ggplot')
# Out:
#   File "/var/folders/n7/l50pjwrd7z55vf740b4n06y00000gn/T/ipykernel_20594/863647369.py", line 2
#     plt.style.use(‘ggplot')
#                   ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train) = {y_train}")
# Out:
# x_train = [1. 2.]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n7/l50pjwrd7z55vf740b4n06y00000gn/T/ipykernel_20594/195819845.py in <module>
#       4 train = np.array([300.0, 500.0])
#       5 print(f"x_train = {x_train}")
# ----> 6 print(f"y_train) = {y_train}")
#
# NameError: name 'y_train' is not defined

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0,500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print (f"Number of training examples is : {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is : 2

# %%
# m is the number of training examples
m = len(x_train)
print (f"Number of training example is: {m}")
# Out:
# Number of training example is: 2

# %%
i = 0 # Change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %%
i = 0 # change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train{i}
print(f"(x^({i}), y^({i})) = ({x_i}), {y_i})
# Out:
#   File "/var/folders/n7/l50pjwrd7z55vf740b4n06y00000gn/T/ipykernel_20594/2405533805.py", line 4
#     y_i = y_train{i}
#                  ^
# SyntaxError: invalid syntax

# %%
i = 0 # change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train{i}
print(f"(x^({i}), y^({i})) = ({x_i}), {y_i}")
# Out:
#   File "/var/folders/n7/l50pjwrd7z55vf740b4n06y00000gn/T/ipykernel_20594/2608272571.py", line 4
#     y_i = y_train{i}
#                  ^
# SyntaxError: invalid syntax

# %%
i = 0 # change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train{i}
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
#   File "/var/folders/n7/l50pjwrd7z55vf740b4n06y00000gn/T/ipykernel_20594/3428561818.py", line 4
#     y_i = y_train{i}
#                  ^
# SyntaxError: invalid syntax

# %%
i = 0 # change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}), {y_i}")
# Out:
# (x^(0), y^(0)) = (1.0), 300.0

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
# Plot the data points
plt.scatter(x_train, y_train, maker='x', c='r')
# set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# set x-axis label
plt.xlabel('Size(1000 sqft)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n7/l50pjwrd7z55vf740b4n06y00000gn/T/ipykernel_20594/1043761953.py in <module>
#       1 # Plot the data points
# ----> 2 plt.scatter(x_train, y_train, maker='x', c='r')
#       3 # set the title
#       4 plt.title("Housing Prices")
#       5 # Set the y-axis label
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2817         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2818         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2819     __ret = gca().scatter(
#    2820         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2821         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4459                 )
#    4460         collection.set_transform(mtransforms.IdentityTransform())
# -> 4461         collection.update(kwargs)
#    4462
#    4463         if colors is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'PathCollection' object has no property 'maker'

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# set x-axis label
plt.xlabel('Size(1000 sqft)')
plt.show()

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %%
w = 100
b = 100
print(f"w:{w}")
print(f"b:{b}")
# Out:
# w:100
# b:100

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      y (ndarray (m,)): target values
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
    return f_wb

# %%
def compute_model_output(x, w, b):
    """
    computes the prediction of a linear model
    Args:
    x(ndarray (m,)): Data, m examples
    w,b (scaler)   : model parameters
    Returns
      y (ndarray(m,)): target values
      """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
        return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction 
plt.plot(x_train, tmp_f_wb, c ='b', label='Our prediction ')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual values')

# Set the title 
plt.title("Housing Prices")

# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')

# Set the x-axis label
plt.xlabel('Size (in 1000 sqft)')
plt.legend()
plt.show()

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction 
plt.plot(x_train, tmp_f_wb, c ='b', label='Our prediction ')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual values')

# Set the title 
plt.title("Housing Prices")

# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')

# Set the x-axis label
plt.xlabel('Size (in 1000 sqft)')
plt.legend()
plt.show()

# %%
w = 200                         
b = 100    
x_i = 1.2
cost_1200sqft = w * x_i + b    

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars

# %%
w = 200
b = 100
x_i = 1.2
cost_1200sqft = w * x_i + b
print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction 
plt.plot(x_train, tmp_f_wb, c ='b', label='Our prediction ')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual values')

# Set the title 
plt.title("Housing Prices")

# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')

# Set the x-axis label
plt.xlabel('Size (in 1000 sqft)')
plt.legend()
plt.show()
